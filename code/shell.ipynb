# %%
! python main.py --data_path='/home/youngjoon/Desktop/ntu_gen_real_npy/' --n_epochs=1
# Out:
# Number of GPUs available: 1
# Total Video Samples: 1198 || Total Participants: 104 || Train Participants: 84 || Validation Participants: 20
# Train samples: 3117 || Validation samples: 477
# Training...
# 100%|████████████████████████████████████████| 390/390 [00:02<00:00, 170.97it/s]
# Epoch: 0 | Loss: 2.2969841957092285
# Testing...
# 100%|████████████████████████████████████████| 390/390 [00:01<00:00, 276.14it/s]
# Model accuracy: 43.471286493423165
# [[143   0   0   0   0   0   2   0  72   0   1   0  13]
#  [  1  84   0   0   5  22   0  78   4  16  32   0  10]
#  [ 21   0  74   0   0   0   4   1  73   3  20   5   6]
#  [ 18   0   5   3   0   0  15   4  85   2  68  20  23]
#  [  0   7   0   0 231   8   0   6   0   3   0   0   0]
#  [  3   0   7   0  36  85   0  56   8  24  20   0   4]
#  [  0  16   3   0   0   2  66   2  43   1 101   6  27]
#  [  0   0   3   0   0  19   0 153   3  15  44   0   0]
#  [  9   0   3   0   0   0   1   0 201   0  26   0  12]
# ...

# %%
! python main.py --data_path='/home/youngjoon/Desktop/ntu_raw_npy/' --n_epochs=1
# Out:
# Number of GPUs available: 1
# Total Video Samples: 1191 || Total Participants: 104 || Train Participants: 84 || Validation Participants: 20
# Train samples: 2982 || Validation samples: 591
# Training...
# 100%|████████████████████████████████████████| 373/373 [00:03<00:00, 113.52it/s]
# Epoch: 0 | Loss: 0.9217536449432373
# Testing...
# 100%|████████████████████████████████████████| 373/373 [00:02<00:00, 137.60it/s]
# Model accuracy: 55.60026827632461
# [[ 86   3  17  43   0   5   5   0  55   0   4   3  10]
#  [  7 107   3   0  15  20   0  19   0  11  15  28  12]
#  [  0   0 190   2   0   6   3   0   6   0   0   0   0]
#  [  3   0   3 174   0   3   3   0  36   0   3   3   6]
#  [  0   6   3   0 219   0   0   3   0   0   0   0   0]
#  [  0   3  12   4  36 105   0   9   6  45   8   0   0]
#  [  8   0   6  53   0   0  91   0  10   0   5  49  18]
#  [  0  41   0   0   9  27   0  68   0  65  25   2   0]
#  [  6   0   6   9   0   3   9   0 189   0   6   3  12]
# ...

# %%
# !python main.py --data_path='/home/youngjoon/Desktop/Dataset/humanact12/' --n_epochs=1000
# Out:
# Number of GPUs available: 1
# Total Video Samples: 1191 || Total Participants: 12 || Train Participants: 10 || Validation Participants: 2
# Train samples: 4825 || Validation samples: 1130
# Training...
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.90it/s]
# Epoch: 0 | Loss: 3.5463614463806152
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.92it/s]
# Epoch: 1 | Loss: 3.5101213455200195
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.91it/s]
# Epoch: 2 | Loss: 3.3986825942993164
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.90it/s]
# Epoch: 3 | Loss: 3.4061691761016846
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.90it/s]
# Epoch: 4 | Loss: 3.2791531085968018
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.89it/s]
# Epoch: 5 | Loss: 3.151402711868286
# ...

# %%
# !python main.py --data_path='/home/youngjoon/Desktop/Dataset/humanact12/' --n_epochs=200
# Out:
# Number of GPUs available: 1
# Total Video Samples: 1191 || Total Participants: 12 || Train Participants: 10 || Validation Participants: 2
# Train samples: 5095 || Validation samples: 860
# Training...
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.87it/s]
# Epoch: 0 | Loss: 3.5243964195251465
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.87it/s]
# Epoch: 1 | Loss: 3.47042179107666
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.86it/s]
# Epoch: 2 | Loss: 3.3230433464050293
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.86it/s]
# Epoch: 3 | Loss: 3.0652105808258057
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.86it/s]
# Epoch: 4 | Loss: 2.9054062366485596
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.86it/s]
# Epoch: 5 | Loss: 2.5773046016693115
# ...

# %%
# !python main.py --data_path='/home/youngjoon/Desktop/Dataset/humanact12/' --n_epochs=300
# Out:
# Number of GPUs available: 1
# Total Video Samples: 1191 || Total Participants: 12 || Train Participants: 10 || Validation Participants: 2
# Train samples: 4765 || Validation samples: 1190
# Training...
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.90it/s]
# Epoch: 0 | Loss: 3.540884494781494
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.91it/s]
# Epoch: 1 | Loss: 3.5128796100616455
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.90it/s]
# Epoch: 2 | Loss: 3.3935887813568115
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.91it/s]
# Epoch: 3 | Loss: 3.4922428131103516
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.90it/s]
# Epoch: 4 | Loss: 3.532613754272461
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.90it/s]
# Epoch: 5 | Loss: 3.4649689197540283
# ...

# %%
# !python main.py --data_path='/home/youngjoon/Desktop/Dataset/humanact12/' --n_epochs=400
# Out:
# Number of GPUs available: 1
# Total Video Samples: 1191 || Total Participants: 12 || Train Participants: 10 || Validation Participants: 2
# Train samples: 4840 || Validation samples: 1115
# Training...
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.86it/s]
# Epoch: 0 | Loss: 3.5512754917144775
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.87it/s]
# Epoch: 1 | Loss: 3.4998881816864014
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.88it/s]
# Epoch: 2 | Loss: 3.4932525157928467
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.87it/s]
# Epoch: 3 | Loss: 3.4948418140411377
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.86it/s]
# Epoch: 4 | Loss: 3.417285442352295
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.86it/s]
# Epoch: 5 | Loss: 3.3886313438415527
# ...

# %%
# !python main.py --data_path='/home/youngjoon/Desktop/Dataset/humanact12/' --n_epochs=500
# Out:
# Number of GPUs available: 1
# Total Video Samples: 1191 || Total Participants: 12 || Train Participants: 10 || Validation Participants: 2
# Train samples: 5040 || Validation samples: 915
# Training...
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.72it/s]
# Epoch: 0 | Loss: 3.5479416847229004
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.74it/s]
# Epoch: 1 | Loss: 3.461113214492798
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.71it/s]
# Epoch: 2 | Loss: 3.435382604598999
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.72it/s]
# Epoch: 3 | Loss: 3.2518367767333984
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.70it/s]
# Epoch: 4 | Loss: 3.071439504623413
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.71it/s]
# Epoch: 5 | Loss: 3.1086649894714355
# ...

# %%
# !python main.py --data_path='/home/youngjoon/Desktop/Dataset/humanact12/' --n_epochs=550
# Out:
# Number of GPUs available: 1
# Total Video Samples: 1191 || Total Participants: 12 || Train Participants: 10 || Validation Participants: 2
# Train samples: 4780 || Validation samples: 1175
# Training...
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.86it/s]
# Epoch: 0 | Loss: 3.4465551376342773
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.92it/s]
# Epoch: 1 | Loss: 3.3598039150238037
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.92it/s]
# Epoch: 2 | Loss: 3.446086883544922
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.81it/s]
# Epoch: 3 | Loss: 3.307281255722046
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.89it/s]
# Epoch: 4 | Loss: 3.220637083053589
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  1.84it/s]
# Epoch: 5 | Loss: 2.9973442554473877
# ...

# %%
# !python main.py --data_path='/home/youngjoon/Desktop/Dataset/mocap_3djoints/' --n_epochs=100
# Out:
# Number of GPUs available: 1
# Total Video Samples: 2514 || Total Participants: 77 || Train Participants: 62 || Validation Participants: 15
# Train samples: 8415 || Validation samples: 4155
# Evaluating mean and std for the training set...
# /home/youngjoon/DEV/ntu-skeleton/code/dataset.py:396: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:204.)
#   X = torch.tensor([self.read_sample(sample_name)[0] for sample_name in self.sample_set])
# Mean and Std saved successfully!
# Training...
#   0%|                                                    | 0/17 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/youngjoon/DEV/ntu-skeleton/code/main.py", line 581, in <module>
#     main(params)
#   File "/home/youngjoon/DEV/ntu-skeleton/code/main.py", line 387, in main
# ...
